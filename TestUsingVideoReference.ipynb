# %%
# %pylab
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
x = array([1.0, 2.0])

# %%
plot(x)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot(x)

# %%
x = 1.0
y = array([1.0,2.0])
z = randn(10,10)
plot (mean(z,0))

# %% [markdown]
# This is a test to see if I can push this notebook to github repository using github desktop.
